# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import array as arr

# %%
N = 340 # number of generations; wanted this to be > 320 (multiple of 32)
generation = np.zeros(N+1) # generation values
n = range(N) # counting array
lst =[]
R = 3.55
j = 0.85 # initial generation value
generation[0] = 0.85
while R < 3.59:
    R += 0.0000001
    for i in n: # loop through generations 0-340
        generation[i+1] = (R*generation[i]*(1-generation[i])) # use logistics equation, find value for each generation
    if '%.6f'%generation[320] == '%.6f'%generation[0] and '%.6f'%generation[16] != '%.6f'%generation[0] and '%.6f'%generation[8] != '%.6f'%generation[0]: # check that period = 32 and period =/= 8 or 16 
        lst.append(R) # record R value that satisfies condition
        print(generation[32])
        print(generation[0])
print("Done")

print(R)
print(lst) # final range of R values that produce sequence with period 32
# Out:
# 0.8318269962421775
# 0.85
# 0.8318278512371892
# 0.85
# 0.8318287062226938
# 0.85
# 0.8318295611986862
# 0.85
# 0.8318304161651826
# 0.85
# 0.8318312711221538
# 0.85
# 0.8318321260696205
# 0.85
# 0.8318329810075722
# 0.85
# 0.8318338359360251
# 0.85
# 0.8318346908549457
# 0.85
# 0.8318355457643621
# 0.85
# 0.8318364006642408
# 0.85
# 0.8318372555546232
# 0.85
# 0.8318381104354715
# 0.85
# 0.8318389653067938
# 0.85
# 0.8318398201685872
# 0.85
# 0.8318406750208773
# 0.85
# 0.8318415298636198
# 0.85
# 0.831842384696839
# 0.85
# 0.8318432395205325
# 0.85
# 0.8318440943346955
# 0.85
# 0.8318449491393026
# 0.85
# 0.8318458039344003
# 0.85
# 0.8318466587199598
# 0.85
# 0.8318475134959787
# 0.85
# 0.8318483682624424
# 0.85
# 0.8318492230193851
# 0.85
# 0.831850077766779
# 0.85
# 0.8318509325046327
# 0.85
# 0.831851787232945
# 0.85
# 0.8318526419517092
# 0.85
# 0.8318534966609182
# 0.85
# 0.8318543513605755
# 0.85
# 0.831855206050692
# 0.85
# 0.8318560607312454
# 0.85
# 0.8318569154022513
# ...
